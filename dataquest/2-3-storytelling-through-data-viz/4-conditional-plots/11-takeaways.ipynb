# %% [markdown]
# # Conditional Plots: Takeaways

# %% [markdown]
# ### Syntax

# %% [markdown]
# - Importing the seaborn module:

# %%
import seaborn as sns

# %% [markdown]
# - Creating a distribution plot:

# %%
sns.distplot(titanic['Fare'])

# %% [markdown]
# - Creating a kernel density plot:

# %%
sns.kdeplot(titanic['Fare'])

# %% [markdown]
# - Shading underneath the curve of a kernel density plot

# %%
sns.kdeplot(titanic['Fare'], shade=True)

# %% [markdown]
# - Setting the Seaborn Style Sheet:

# %%
sns.set_style("white")

# %% [markdown]
# - Removing the Spines (default: only top and right Spines are removed)

# %%
sns.despine(left=True, bottom=True)

# %% [markdown]
# - Generating a grid of data containing a subset od the data for different values:

# %%
g = sns.FacetGrid(titanic, col='Pclass', height=6)

# %% [markdown]
# - Generating a grid of data with multiple subsets of data

# %%
g = sns.FacetGrid(titanic, col='Pclass', row='Survived', height=6)

# %% [markdown]
# - Adding different colors for unique values using hue:

# %%
g = sns.FacetGrid(titanic, col='Pclass', row='Survived', hue='Sex', height=6)

# %% [markdown]
# - Using a grid of data and mapping it onto a Seaborn object:

# %%
g.map(sns.kdeplot, "Age", shade=True)

# %% [markdown]
# - Adding a legend to the grid of data:

# %%
g.add_legend()

# %% [markdown]
# ### Concepts

# %% [markdown]
# - Seaborn:
#     - is built on top of matplotlib.
#     - has good support for more complete plots.
#     - attractice default styles
#     - integrates well with the pandas library.
# - Seaborn creates a matplotlib figure or adds to the current existing figure.
# - Seaborn comes with a few style sheets:
#     - `darkgrid`: Coordiante grid displayed, dark background color
#     - `whitegrid`: Coordinate grid displayed, white background color
#     - `dark`: Coordinate grid hidden, dark background color
#     - `white`: Coordinate grid hidden, white background color
#     - `ticks`: Coordinate grid hidden, white background color, ticks visible
