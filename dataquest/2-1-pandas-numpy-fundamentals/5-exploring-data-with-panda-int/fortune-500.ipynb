# %% [markdown]
# ### Introduction

# %%
import pandas as pd
import numpy as np

# read the data set into a pandas dataframe
f500 = pd.read_csv("f500.csv", index_col=0)
f500.index.name = None

# replace 0 values in the "previous_rank" column with NaN
f500.loc[f500["previous_rank"] == 0, "previous_rank"] = np.nan

# %% [markdown]
# 1. Select the `rank`, `revenues`, and `revenue_change` columns in `f500`. Then, use the `DataFrame.head()` method to select the first 5 rows. Assign the result to `f500_selection`.

# %%
f500_selection = f500[["rank", "revenues", "revenue_change"]].head()

# %%
f500_selection
# Out:
#                           rank  revenues  revenue_change
# Walmart                      1    485873             0.8
# State Grid                   2    315199            -4.4
# Sinopec Group                3    267518            -9.1
# China National Petroleum     4    262573           -12.3
# Toyota Motor                 5    254694             7.7

# %% [markdown]
# ### Reading CSV files with pandas

# %% [markdown]
# 1. Use the `pandas.read_csv()` function to read the `f500.csv` CSV file as a pandas dataframe. Assign it to the variable name `f500`.
# - Do not use the `index_col` parameter.
# 2. Use the code below to insert the NaN values into the `previous_rank` column:
#
# `f500.loc[f500["previous_rank"] == 0, "previous_rank"] = np.nan`

# %%
f500 = pd.read_csv("f500.csv")
f500.loc[f500["previous_rank"] == 0, "previous_rank"] = np.nan

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %% [markdown]
# ### Using iloc to Select by Integer Position

# %% [markdown]
# Without using the `index_col` parameter:
# - The `company` column is now included as a regular column, instead of being used for the index.
# - The index labels are now integers starting from `0`.
#
# _Note_: This is the more conventional way to read in a dataframe and will be used from here on out.
#
# We can use _integer positions_ to select data using `DataFrame.iloc[]` and `Series.iloc[]`.
# - **l**oc: **l**abel based selection
# - **i**loc: **integer** position based selection
#
# **Syntax**
#
# `df.iloc[row_index, column_index]`

# %% [markdown]
# 1. Select just the fifth row of the `f500` dataframe. Assign the result to `fifth_row`.

# %%
fifth_row = f500.iloc[4]

# %%
fifth_row
# Out:
# company                                     Toyota Motor
# rank                                                   5
# revenues                                          254694
# revenue_change                                       7.7
# profits                                          16899.3
# assets                                            437575
# profit_change                                      -12.3
# ceo                                          Akio Toyoda
# industry                        Motor Vehicles and Parts
# sector                            Motor Vehicles & Parts
# previous_rank                                          8
# country                                            Japan
# hq_location                                Toyota, Japan
# website                     http://www.toyota-global.com
# years_on_global_500_list                              23
# employees                                         364445
# ...

# %% [markdown]
# 2. Select the value in the first row of the `company` column. Assign the result to `company_value`.

# %%
company_value = f500["company"].iloc[0]

# %%
company_value
# Out:
# 'Walmart'

# %% [markdown]
# ### Using iloc to Select by Integer Position (Continued)

# %% [markdown]
# To select a whole column:

# %%
first_column = f500.iloc[:, 0]
first_column
# Out:
# 0                             Walmart
# 1                          State Grid
# 2                       Sinopec Group
# 3            China National Petroleum
# 4                        Toyota Motor
#                     ...
# 495    Teva Pharmaceutical Industries
# 496          New China Life Insurance
# 497         Wm. Morrison Supermarkets
# 498                               TUI
# 499                        AutoNation
# Name: company, Length: 500, dtype: object

# %% [markdown]
# To select a positional slice:

# %%
second_to_sixth_rows = f500[1:5]
second_to_sixth_rows
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change            ceo                  industry  \
# 1           -6.2        Kou Wei                 Utilities
# 2          -65.0      Wang Yupu        Petroleum Refining
# 3          -73.7  Zhang Jianhua        Petroleum Refining
# 4          -12.3    Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country     hq_location  \
# 1                  Energy            2.0   China  Beijing, China
# 2                  Energy            4.0   China  Beijing, China
# 3                  Energy            3.0   China  Beijing, China
# ...

# %% [markdown]
# - With `loc[]`, the ending slice **is** included.
# - With `iloc[]`, the ending slice **is not** included.

# %% [markdown]
# | Select by integer position | Explicit Syntax | Shorthand Convention |
# | :--- | :--- | :---|
# | Single column from dataframe | `df.iloc[:,[3,5,6]]` | |
# | List of columns from dataframe | `df.iloc[:,3]` | |
# | Slice of columns from dataframe | `df.iloc[:,3:7]` | |
# | Single row from dataframe | `df.iloc[20]` | |
# | List of rows from dataframe | `df.iloc[[0,3,8]]` | |
# | Slice of rows from dataframe | `df.iloc[3:5]` | `df[3:5]` |
# | Single items from series | `s,iloc[8]` | `s[8]` |
# | List of items from series | `s.iloc[[2,8,1]]` | `s[[2,8,1]]` |
# | Slice of items from series | `s.iloc[5:10]` | `s[5:10]` |

# %% [markdown]
# 1. Select the first three rows of the `f500` dataframe. Assign the result to `first_three_rows`.

# %%
first_three_rows = f500.iloc[:3]
first_three_rows
# Out:
#          company  rank  revenues  revenue_change  profits  assets  \
# 0        Walmart     1    485873             0.8  13643.0  198825
# 1     State Grid     2    315199            -4.4   9571.3  489838
# 2  Sinopec Group     3    267518            -9.1   1257.9  310726
#
#    profit_change                  ceo               industry     sector  \
# 0           -7.2  C. Douglas McMillon  General Merchandisers  Retailing
# 1           -6.2              Kou Wei              Utilities     Energy
# 2          -65.0            Wang Yupu     Petroleum Refining     Energy
#
#    previous_rank country      hq_location                 website  \
# 0            1.0     USA  Bentonville, AR  http://www.walmart.com
# 1            2.0   China   Beijing, China  http://www.sgcc.com.cn
# 2            4.0   China   Beijing, China  http://www.sinopec.com
#
#    years_on_global_500_list  employees  total_stockholder_equity
# 0                        23    2300000                     77798
# ...

# %% [markdown]
# 2. Select the first and seventh rows and the first five columns of the `f500` dataframe. Assign the result to `first_seventh_row_slice`.

# %%
first_seventh_row_slice = f500.iloc[[0,6], :5]
first_seventh_row_slice
# Out:
#              company  rank  revenues  revenue_change  profits
# 0            Walmart     1    485873             0.8  13643.0
# 6  Royal Dutch Shell     7    240033           -11.8   4575.0

# %% [markdown]
# ### Using pandas Methods to Create Boolean Masks

# %% [markdown]
# Use `Series.isnull()` to view rows with null values in the `revenue_change` column:

# %%
rev_is_null = f500["revenue_change"].isnull()
rev_is_null.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: revenue_change, dtype: bool

# %%
rev_change_null = f500[rev_is_null]
rev_change_null[["company", "country", "sector"]]
# Out:
#                         company  country      sector
# 90                       Uniper  Germany      Energy
# 180  Hewlett Packard Enterprise      USA  Technology

# %% [markdown]
# 1. Use the `Series.isnull()` method to select all rows from `f500` that have a null value for the `previous_rank` column. Select only the `company`, `rank`, and `previous_rank` columns. Assign the result to `null_previous_rank`.

# %%
null_previous_rank = f500[f500["previous_rank"].isnull()][["company", "rank", "previous_rank"]]
null_previous_rank
# Out:
#                                    company  rank  previous_rank
# 48                   Legal & General Group    49            NaN
# 90                                  Uniper    91            NaN
# 123                      Dell Technologies   124            NaN
# 138                 Anbang Insurance Group   139            NaN
# 140                        Albertsons Cos.   141            NaN
# 180             Hewlett Packard Enterprise   181            NaN
# 267                           Hengli Group   268            NaN
# 271         Johnson Controls International   272            NaN
# 341                                  Chubb   342            NaN
# 375                 Charter Communications   376            NaN
# 376                              Medtronic   377            NaN
# 392                               Facebook   393            NaN
# 409                            Kraft Heinz   410            NaN
# 414                                  Nokia   415            NaN
# ...

# %% [markdown]
# ### Working with Integer Labels

# %% [markdown]
# If we wanted to select the first company from our new `null_previous_rank` dataframe by _integer position_, we can use `DataFrame.iloc[]`:

# %%
first_null_prev_rank = null_previous_rank.iloc[0]
first_null_prev_rank
# Out:
# company          Legal & General Group
# rank                                49
# previous_rank                      NaN
# Name: 48, dtype: object

# %% [markdown]
# If we wanted to select a row using `loc[]`, we'd have to use the integer label for the first row -- `48`.

# %% [markdown]
# 1. Assign the first five rows of the `null_previous_rank` dataframe to the variable `top5_null_prev_rank` by choosing the correct method out of either `loc[]` or `iloc[]`.

# %%
null_previous_rank = f500[f500["previous_rank"].isnull()]
null_previous_rank
# Out:
#                                    company  rank  revenues  revenue_change  \
# 48                   Legal & General Group    49    105235           442.3
# 90                                  Uniper    91     74407             NaN
# 123                      Dell Technologies   124     64806            18.1
# 138                 Anbang Insurance Group   139     60800           124.0
# 140                        Albertsons Cos.   141     59678             1.6
# 180             Hewlett Packard Enterprise   181     50123             NaN
# 267                           Hengli Group   268     37880            12.2
# 271         Johnson Controls International   272     37674            -6.3
# 341                                  Chubb   342     31469            65.7
# 375                 Charter Communications   376     29003           197.3
# 376                              Medtronic   377     28833            42.3
# ...

# %%
top5_null_prev_rank = null_previous_rank.iloc[:5]
top5_null_prev_rank
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 48    Legal & General Group    49    105235           442.3   1697.9  577954
# 90                   Uniper    91     74407             NaN  -3557.5   51541
# 123       Dell Technologies   124     64806            18.1  -1672.0  118206
# 138  Anbang Insurance Group   139     60800           124.0   3883.9  430040
# 140         Albertsons Cos.   141     59678             1.6   -373.3   23755
#
#      profit_change               ceo                          industry  \
# 48             3.4      Nigel Wilson   Insurance: Life, Health (stock)
# 90             NaN     Klaus Schafer                            Energy
# 123            NaN   Michael S. Dell       Computers, Office Equipment
# 138            0.9        Wu Xiaohui  Insurance: Life, Health (Mutual)
# 140            NaN  Robert G. Miller              Food and Drug Stores
#
#                  sector  previous_rank  country          hq_location  \
# ...

# %% [markdown]
# ### Pandas Index Alignment

# %% [markdown]
# Now that we've identified the rows with null values in the `previous_rank` column, let's use the `Series.notnull()` method to exclude them from the next part of the analysis.

# %%
previously_ranked = f500[f500["previous_rank"].notnull()]

# %% [markdown]
# Then create a `rank_change` column by subtracting the `rank` column from the `previous_rank` column:

# %%
rank_change = previously_ranked["previous_rank"] - previously_ranked["rank"]
rank_change.shape
# Out:
# (467,)

# %%
rank_change.tail(3)
# Out:
# 496   -70.0
# 497   -61.0
# 498   -32.0
# dtype: float64

# %% [markdown]
# Since the `rank_change` has 467 rows and the last integer index label is 498, we know that our index labels no longer align wiht the integer positions.
#
# Suppose now we decided to add the `rank_change` series to the `f500` dataframe as a new column. Its index labels no longer match the index labels in `f500`, so how can this be done?
#
# Another powerful aspect of pandas is that almost every operation will align on the index labels. The pandas library will align on index at every opportunity, no matter if our index labels are strings or integers -- this makes working with data from different sources or working with data when we have removed, added, or reordered rows much easier than it would be otherwise.

# %% [markdown]
# 1. Use the `Series.notnull()` method to select all rows from `f500` that have a non-null value for the `previous_rank` column. Assign the result to `previously_ranked`.

# %%
previously_ranked = f500[f500["previous_rank"].notnull()]

# %% [markdown]
# 2. From the `previously_ranked` dataframe, subtract the `rank` column from the `previous_rank` column. Assign the result to `rank_change`.

# %%
rank_change = previously_ranked["previous_rank"] - previously_ranked["rank"]

# %% [markdown]
# 3. Assign the values in the `rank_change` to a new column in the `f500` dataframe, `"rank_change"`.

# %%
f500["rank_change"] = rank_change

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %% [markdown]
# ### Using Boolean Operators

# %%
cols = ["company", "revenues", "country"]
f500_sel = f500[cols].head()
f500_sel
# Out:
#                     company  revenues country
# 0                   Walmart    485873     USA
# 1                State Grid    315199   China
# 2             Sinopec Group    267518   China
# 3  China National Petroleum    262573   China
# 4              Toyota Motor    254694   Japan

# %%
over_265 = f500_sel["revenues"] > 265000
china = f500_sel["country"] == "China"
combined = over_265 & china

# %%
combined
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
final_cols = ["company", "revenues"]
result = f500_sel.loc[combined, final_cols]
result
# Out:
#          company  revenues
# 1     State Grid    315199
# 2  Sinopec Group    267518

# %% [markdown]
# 1. Select all companies with revenues over 100 billion and negative profits from the `f500` dataframe. The result should include all columns.
# - Create a boolean array that selects the companies with revenues greater than 100 billion. Assign the result to `large_revenue`.
# - Create a boolean array that selects the companies with profits less than 0. Assign the result to `negative_profits`.
# - Combine `large_revenue` and `negative_profits`. Assign the result to `combined`.
# - Use `combined` to filter `f500`. Assign the result to `big_rev_neg_profit`.

# %%
large_revenue = f500["revenues"] > 100000
negative_profits = f500["profits"] < 0
combined = large_revenue & negative_profits
big_rev_neg_profit = f500[combined]
big_rev_neg_profit
# Out:
#                 company  rank  revenues  revenue_change  profits   assets  \
# 32  Japan Post Holdings    33    122990             3.6   -267.4  2631385
# 44              Chevron    45    107567           -18.0   -497.0   260078
#
#     profit_change               ceo                         industry  \
# 32         -107.5  Masatsugu Nagato  Insurance: Life, Health (stock)
# 44         -110.8    John S. Watson               Petroleum Refining
#
#         sector  previous_rank country    hq_location                  website  \
# 32  Financials           37.0   Japan   Tokyo, Japan  http://www.japanpost.jp
# 44      Energy           31.0     USA  San Ramon, CA   http://www.chevron.com
#
#     years_on_global_500_list  employees  total_stockholder_equity  rank_change
# 32                        21     248384                     91532          4.0
# 44                        23      55200                    145556        -14.0

# %% [markdown]
# ### Using Boolean Operators Continued

# %% [markdown]
# A more concise way of writing the above code is to remove the intermediate variables `large_revenue` and `negative_profits`:
#
# `combined = (f500["revenues"] > 100000) & (f500["profits"] < 0)`
#
# OR
#
# `big_rev_neg_profit = f500[(f500["revenues"] > 100000) & (f500["profits"] < 0)]`

# %% [markdown]
# 1. Select all rows for companies whose `country` value is either Brazil or Venezuela. Assign the result to `brazil_venezuela`.

# %%
brazil_venezuela = f500[(f500["country"] == "Brazil") | (f500["country"] == "Venezuela")]
brazil_venezuela
# Out:
#                              company  rank  revenues  revenue_change  profits  \
# 74                         Petrobras    75     81405           -16.3  -4838.0
# 112            Itau Unibanco Holding   113     66876            21.4   6666.4
# 150                  Banco do Brasil   151     58093           -13.4   2013.8
# 153                   Banco Bradesco   154     57443            31.3   5127.9
# 190                              JBS   191     48825            -0.1    107.7
# 369                             Vale   370     29363            14.7   3982.0
# 441  Mercantil Servicios Financieros   442     24403            50.3   2004.2
# 486                Ultrapar Holdings   487     22167            -2.3    447.5
#
#      assets  profit_change                        ceo  \
# 74   246983            NaN       Pedro Pullen Parente
# 112  415972          -13.7    Candido Botelho Bracher
# 150  426416          -52.3   Paulo Rogerio Caffarelli
# ...

# %% [markdown]
# 2. Select the first five companies in the Technology sector for which the country is **not** the USA from the `f500` dataframe. Assign the result to `tech_outside_usa`.

# %%
tech_outside_usa = f500[(f500["sector"] == "Technology") & (f500["country"] != "USA")].head()
tech_outside_usa
# Out:
#                          company  rank  revenues  revenue_change  profits  \
# 14           Samsung Electronics    15    173957            -2.0  19316.5
# 26    Hon Hai Precision Industry    27    135129            -4.3   4608.8
# 70                       Hitachi    71     84558             1.2   2134.3
# 82   Huawei Investment & Holding    83     78511            24.9   5579.4
# 104                         Sony   105     70170             3.9    676.4
#
#      assets  profit_change                   ceo  \
# 14   217104           16.8          Oh-Hyun Kwon
# 26    80436           -0.4             Terry Gou
# 70    86742           48.8  Toshiaki Higashihara
# 82    63837           -5.0          Ren Zhengfei
# 104  158519          -45.1           Kazuo Hirai
#
#                                        industry      sector  previous_rank  \
# 14               Electronics, Electrical Equip.  Technology           13.0
# ...

# %% [markdown]
# ### Sorting Values

# %% [markdown]
# Select the company that employs the most people in China by first selecting all of the rows where the `country` column equals `China`:

# %%
selected_rows = f500[f500["country"] == "China"]

# %% [markdown]
# Use the `DataFrame.sort_values()` method to sort the rows on the `employees` column by passing the column name to the method:

# %%
sorted_rows = selected_rows.sort_values("employees")
sorted_rows[["company", "country", "employees"]].head()
# Out:
#                                 company country  employees
# 204                         Noble Group   China       1000
# 458             Yango Financial Holding   China      10234
# 438  China National Aviation Fuel Group   China      11739
# 128                         Tewoo Group   China      17353
# 182            Amer International Group   China      17852

# %% [markdown]
# By default, the `sort_values()` method will sort the rows in _ascending_ order. To sort the rows in _descending_ order instead, we can set the `ascending` parameter to `False`.

# %%
sorted_rows = selected_rows.sort_values("employees", ascending=False)
sorted_rows[["company", "country", "employees"]].head()
# Out:
#                         company country  employees
# 3      China National Petroleum   China    1512048
# 118            China Post Group   China     941211
# 1                    State Grid   China     926067
# 2                 Sinopec Group   China     713288
# 37   Agricultural Bank of China   China     501368

# %% [markdown]
# 1. Find the company headquartered in Japan with the largest number of employees.
# - Select only the rows that have a country name equal to `Japan`.
# - Use `DataFrame.sort_values()` to sort those rows _by_ the `employees` column in _descending_ order.
# - Use `DataFrame.iloc[]` to select the first row from the sorted dataframe.
# - Extract the company name from the index label `company` from the first row. Assign the result to `top_japanese_employer`.

# %%
selected_rows = f500[f500["country"] == "Japan"]
selected_rows
# Out:
#                              company  rank  revenues  revenue_change  profits  \
# 4                       Toyota Motor     5    254694             7.7  16899.3
# 28                       Honda Motor    29    129198             6.2   5690.3
# 32               Japan Post Holdings    33    122990             3.6   -267.4
# 43                      Nissan Motor    44    108164             6.5   6123.4
# 49      Nippon Telegraph & Telephone    50    105128             9.4   7384.4
# 70                           Hitachi    71     84558             1.2   2134.3
# 71                    SoftBank Group    72     82892             8.4  13163.4
# 86                              AEON    87     75772            11.8    103.9
# 104                             Sony   105     70170             3.9    676.4
# 109                        Panasonic   110     67775             6.7   1378.4
# 110            Nippon Life Insurance   111     67388             0.4   2786.9
# ...

# %%
sorted_rows = selected_rows.sort_values("employees", ascending=False)
sorted_rows
# Out:
#                              company  rank  revenues  revenue_change  profits  \
# 4                       Toyota Motor     5    254694             7.7  16899.3
# 70                           Hitachi    71     84558             1.2   2134.3
# 49      Nippon Telegraph & Telephone    50    105128             9.4   7384.4
# 86                              AEON    87     75772            11.8    103.9
# 109                        Panasonic   110     67775             6.7   1378.4
# 32               Japan Post Holdings    33    122990             3.6   -267.4
# 419     Sumitomo Electric Industries   420     25975             6.3    992.7
# 28                       Honda Motor    29    129198             6.2   5690.3
# 346                            Canon   347     31271            -0.4   1385.0
# 236                          Fujitsu   237     41620             5.4    816.7
# 235                            Denso   236     41781            10.9   2377.6
# ...

# %%
top_japanese_employer = sorted_rows.iloc[0]["company"]
top_japanese_employer
# Out:
# 'Toyota Motor'

# %% [markdown]
# ### Using Loops with pandas

# %% [markdown]
# Loops for the purpose of aggregation:
#
# If we wanted to calcualte the average revenue for each country in the data set, our process may look like this:
# - Identify each unique country in the data set using the `Series.unique()` method.
# - For each country:
#     - Select only the rows corresponding to that country.
#     - Calculate the average revenue for those rows.

# %%
# Create an empty dictionary to store the results
avg_rev_by_country = {}

# Create an array of unique countries
countries = f500["country"].unique()

# Use a for loop to iterate over the countries
for c in countries:
    # Use boolean comparison to select only rows that
    # correspond to a specific country
    selected_rows = f500[f500["country"] == c]
    # Calculate the mean average revenue for just those rows
    mean = selected_rows["revenues"].mean()
    # Assign the mean value to the dictionary, using the
    # country name as the key
    avg_rev_by_country[c] = mean

# %%
avg_rev_by_country
# Out:
# {'USA': 64218.371212121216,
#  'China': 55397.880733944956,
#  'Japan': 53164.03921568627,
#  'Germany': 63915.0,
#  'Netherlands': 61708.92857142857,
#  'Britain': 51588.708333333336,
#  'South Korea': 49725.6,
#  'Switzerland': 51353.57142857143,
#  'France': 55231.793103448275,
#  'Taiwan': 46364.666666666664,
#  'Singapore': 54454.333333333336,
#  'Italy': 51899.57142857143,
#  'Russia': 65247.75,
#  'Spain': 40600.666666666664,
#  'Brazil': 52024.57142857143,
#  'Mexico': 54987.5,
#  'Luxembourg': 56791.0,
#  'India': 39993.0,
#  'Malaysia': 49479.0,
#  'Thailand': 48719.0,
#  'Australia': 33688.71428571428,
#  'Belgium': 45905.0,
#  'Norway': 45873.0,
#  'Canada': 31848.0,
#  'Ireland': 32819.5,
#  'Indonesia': 36487.0,
#  'Denmark': 35464.0,
#  'Saudi Arabia': 35421.0,
#  'Sweden': 27963.666666666668,
#  'Finland': 26113.0,
#  'Venezuela': 24403.0,
#  'Turkey': 23456.0,
#  'U.A.E': 22799.0,
#  'Israel': 21903.0}

# %% [markdown]
# 1. Create an empty dictionary, `top_employer_by_country` to store the results of the exercise.

# %%
top_employer_by_country = {}

# %% [markdown]
# 2. Use the `Series.unique()` method to create an array of unique values from the `country` column.

# %%
countries = f500["country"].unique()
countries
# Out:
# array(['USA', 'China', 'Japan', 'Germany', 'Netherlands', 'Britain',
#        'South Korea', 'Switzerland', 'France', 'Taiwan', 'Singapore',
#        'Italy', 'Russia', 'Spain', 'Brazil', 'Mexico', 'Luxembourg',
#        'India', 'Malaysia', 'Thailand', 'Australia', 'Belgium', 'Norway',
#        'Canada', 'Ireland', 'Indonesia', 'Denmark', 'Saudi Arabia',
#        'Sweden', 'Finland', 'Venezuela', 'Turkey', 'U.A.E', 'Israel'],
#       dtype=object)

# %% [markdown]
# 3. Use a for loop to iterate over the array unqiue countries. In each iteration:
# - Select only the rows that have a country name equal to the current iteration.
# - Use `DataFrame.sort_values()` to sort those rows _by_ the `employees` column in _descending_ order.
# - Select the first row from the sorted dataframe.
# - Extract the company name from the index label `company` from the first row.
# - Assign the results to the `top_employer_by_country` dictionary, using the country name as the key, and the compnay name as the value.

# %%
for c in countries:
    selected_rows = f500[f500["country"] == c]
    sorted_rows = selected_rows.sort_values("employees", ascending=False)
    top_employer = sorted_rows.iloc[0]
    employer_name = top_employer["company"]
    top_employer_by_country[c] = employer_name

# %%
top_employer_by_country
# Out:
# {'USA': 'Walmart',
#  'China': 'China National Petroleum',
#  'Japan': 'Toyota Motor',
#  'Germany': 'Volkswagen',
#  'Netherlands': 'EXOR Group',
#  'Britain': 'Compass Group',
#  'South Korea': 'Samsung Electronics',
#  'Switzerland': 'Nestle',
#  'France': 'Sodexo',
#  'Taiwan': 'Hon Hai Precision Industry',
#  'Singapore': 'Flex',
#  'Italy': 'Poste Italiane',
#  'Russia': 'Gazprom',
#  'Spain': 'Banco Santander',
#  'Brazil': 'JBS',
#  'Mexico': 'America Movil',
#  'Luxembourg': 'ArcelorMittal',
#  'India': 'State Bank of India',
#  'Malaysia': 'Petronas',
#  'Thailand': 'PTT',
#  'Australia': 'Wesfarmers',
#  'Belgium': 'Anheuser-Busch InBev',
#  'Norway': 'Statoil',
#  'Canada': 'George Weston',
#  'Ireland': 'Accenture',
#  'Indonesia': 'Pertamina',
#  'Denmark': 'Maersk Group',
#  'Saudi Arabia': 'SABIC',
#  'Sweden': 'H & M Hennes & Mauritz',
#  'Finland': 'Nokia',
#  'Venezuela': 'Mercantil Servicios Financieros',
#  'Turkey': 'Koc Holding',
#  'U.A.E': 'Emirates Group',
# ...

# %% [markdown]
# ### Challenge: Calculating Return on Assets by Country

# %% [markdown]
# Return on assets (ROA) is a business-specific metric which indicates a company's ability to make profit using their available assets.
#
# `return on assets = profit / assets`

# %% [markdown]
# 1. Create a new column `roa` in the `f500` dataframe, containing the return on assets metric for each company.

# %%
f500["roa"] = f500["profits"] / f500["assets"]
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %% [markdown]
# 2. Aggregate the data by the `sector` column, and create a dictionary `top_roa_by_sector`, with:
# - Dictionary keys with the sector name.
# - Dictionary values with the company name with the highest ROA value from that sector.

# %%
top_roa_by_sector = {}

# %%
for sector in f500["sector"].unique():
    is_sector = f500["sector"] == sector
    sector_companies = f500.loc[is_sector]
    top_company = sector_companies.sort_values("roa", ascending=False).iloc[0]
    company_name = top_company["company"]
    top_roa_by_sector[sector] = company_name

# %%
top_roa_by_sector
# Out:
# {'Retailing': 'H & M Hennes & Mauritz',
#  'Energy': 'National Grid',
#  'Motor Vehicles & Parts': 'Subaru',
#  'Financials': 'Berkshire Hathaway',
#  'Technology': 'Accenture',
#  'Wholesalers': 'McKesson',
#  'Health Care': 'Gilead Sciences',
#  'Telecommunications': 'KDDI',
#  'Engineering & Construction': 'Pacific Construction Group',
#  'Industrials': '3M',
#  'Food & Drug Stores': 'Publix Super Markets',
#  'Aerospace & Defense': 'Lockheed Martin',
#  'Food, Beverages & Tobacco': 'Philip Morris International',
#  'Household Products': 'Unilever',
#  'Transportation': 'Delta Air Lines',
#  'Materials': 'CRH',
#  'Chemicals': 'LyondellBasell Industries',
#  'Media': 'Disney',
#  'Apparel': 'Nike',
#  'Hotels, Restaurants & Leisure': 'McDonald’s',
#  'Business Services': 'Adecco Group'}
